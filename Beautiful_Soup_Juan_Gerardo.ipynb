# %%
import requests

# %%
DATA_URL = "https://www.worldometers.info/world-population/world-population-by-year/"

# %%
data = requests.get(DATA_URL)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.content)

# %%
tables = soup.find_all('table')
# Out:
# [<table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":false,"sortable":false,"pageSize":false}' data-sort-col="-1" data-sort-dir="asc"> <thead> <tr> <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false"> <span>Year</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Population</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly %<br/>Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Net<br/>Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Density<br/>(P/Km²)</span> </th> </tr> </thead> <tbody> <tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2025"> 2025 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8231613070"> 8,231,613,070 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="85"> 0.85% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="69640498"> 69,640,498 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="55.26798086477776"> 55 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2024"> 2024 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8161972572"> 8,161,972,572 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="87"> 0.87% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="70237642"> 70,237,642 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="54.80040668725661"> 55 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2023"> 2023 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8091734930"> 8,091,734,930 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="88"> 0.88% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="70327738"> 70,327,738 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="54.328823217402984"> 54 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2022"> 2022 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8021407192"> 8,021,407,192 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="84"> 0.84% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="66958801"> 66,958,801 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="53.856634832818585"> 54 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2021"> 2021 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="7954448391"> 7,954,448,391 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="86"> 0.86% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="67447099"> 67,447,099 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="53.40706587216329"> 53 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="2020"> 2020 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="7887001292"> 7,887,001,292 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="97"> 0.97% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" da ...

# %%
import pandas as pd

# %%
df = pd.read_html(str(tables))
df = df[0]
df = df.fillna(0)
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_6564\2925780987.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables))
#     Year  Population Yearly % Change  Net Change  Density (P/Km²)
# 0   2025  8231613070           0.85%  69640498.0               55
# 1   2024  8161972572           0.87%  70237642.0               55
# 2   2023  8091734930           0.88%  70327738.0               54
# 3   2022  8021407192           0.84%  66958801.0               54
# 4   2021  7954448391           0.86%  67447099.0               53
# ..   ...         ...             ...         ...              ...
# 88   900   240000000               0         0.0                2
# 89   800   220000000               0         0.0                1
# 90   700   210000000               0         0.0                1
# 91   600   200000000               0         0.0                1
# 92   200   190000000               0         0.0                1
#
# [93 rows x 5 columns]

# %%
df.to_csv(r"data|")
